# %% [markdown]
# # Date preperation

# %% [markdown]
# Libaries importeren

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz

# %% [markdown]
# # pivot tabellen maken
# tags met alleen de recepten zonder noten en lunch & diner

# %%
recepten_df=pd.read_csv("Generated Datasets/Filter_noten_maaltijd_DF.csv")
recepten = recepten_df.iloc[:,0].tolist()

tags = pd.read_csv('/data/foodboost/tags.csv')
tags = tags[tags['recipe'].str.contains('|'.join(recepten))]
# Out:
# /tmp/ipykernel_14572/4214086887.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   tags = tags[tags['recipe'].str.contains('|'.join(recepten))]

# %%
tags_pivot = tags.pivot_table(values="recipe", index= tags.recipe, columns="tag", aggfunc="count")
tags_pivot= tags_pivot.fillna(0)

# %% [markdown]
# Ingrediënten

# %%
ingr = pd.read_csv('/data/foodboost/ingredients.csv')
ingr = ingr[ingr['recipe'].str.contains('|'.join(recepten))]

ingr_pivot = ingr.pivot_table(values="recipe", index= ingr.recipe, columns="ingredient", aggfunc="count")
ingr_pivot= ingr_pivot.fillna(0)
# Out:
# /tmp/ipykernel_14572/3991348774.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ingr = ingr[ingr['recipe'].str.contains('|'.join(recepten))]

# %% [markdown]
# Variabele defineren

# %%
ingr_pivot_columnnames= ingr_pivot.columns.values.tolist()
lengte= len(ingr_pivot_columnnames)
dubbele_ingr= []
grens_ratio= 85
ingr_pivot_copy= ingr_pivot.copy()

# %% [markdown]
# Dubbele kolomnamen zoeken

# %%
for i in range(lengte):
    if i < (lengte-1):
        Ratio = fuzz.token_sort_ratio(ingr_pivot_columnnames[i],ingr_pivot_columnnames[i+1])
        if Ratio > grens_ratio:
            dubbele_ingr.append((ingr_pivot_columnnames[i], ingr_pivot_columnnames[i+1]))

# %% [markdown]
# Dubbele kolommen samenvoegen en de extra verwijderen

# %%
ingr_pivot_copy= ingr_pivot.copy()
for i in dubbele_ingr:
    ingr_pivot_copy[i[1]] = ingr_pivot_copy[i[0]] + ingr_pivot_copy[i[1]]
    ingr_pivot_copy=ingr_pivot_copy.drop([i[0]], axis=1)

# %% [markdown]
# # output

# %%
ingr_pivot_copy
# Out:
# ingredient                                          (arachide)olie  \
# recipe
#  Andijviestamppot met gebakken salami                          0.0
#  Libanese wraps met appel-koolsalade                           0.0
#  Plaattaart met gegrilde groenten en witte kaas                0.0
#  Zalmspies met sojaglaze van de BBQ                            0.0
# &amp;Suus’ buik-weg-salade                                     0.0
# ...                                                            ...
# Zweedse gehaktballetjes                                        0.0
# Zweedse gehaktballetjes met room                               0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli             0.0
# Zwitserse kaasfondue                                           0.0
# ‘Nasi’ met Hollandse soepgroente                               0.0
#
# ingredient                                          (herten)biefstukken  \
# recipe
#  Andijviestamppot met gebakken salami                               0.0
#  Libanese wraps met appel-koolsalade                                0.0
#  Plaattaart met gegrilde groenten en witte kaas                     0.0
#  Zalmspies met sojaglaze van de BBQ                                 0.0
# &amp;Suus’ buik-weg-salade                                          0.0
# ...                                                                 ...
# Zweedse gehaktballetjes                                             0.0
# Zweedse gehaktballetjes met room                                    0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                  0.0
# Zwitserse kaasfondue                                                0.0
# ‘Nasi’ met Hollandse soepgroente                                    0.0
#
# ingredient                                          (houdbare) melk  \
# recipe
#  Andijviestamppot met gebakken salami                           0.0
#  Libanese wraps met appel-koolsalade                            0.0
#  Plaattaart met gegrilde groenten en witte kaas                 0.0
#  Zalmspies met sojaglaze van de BBQ                             0.0
# &amp;Suus’ buik-weg-salade                                      0.0
# ...                                                             ...
# Zweedse gehaktballetjes                                         0.0
# Zweedse gehaktballetjes met room                                0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli              0.0
# Zwitserse kaasfondue                                            0.0
# ‘Nasi’ met Hollandse soepgroente                                0.0
#
# ingredient                                          (magere) shoarmareepjes  \
# recipe
#  Andijviestamppot met gebakken salami                                   0.0
#  Libanese wraps met appel-koolsalade                                    0.0
#  Plaattaart met gegrilde groenten en witte kaas                         0.0
#  Zalmspies met sojaglaze van de BBQ                                     0.0
# &amp;Suus’ buik-weg-salade                                              0.0
# ...                                                                     ...
# Zweedse gehaktballetjes                                                 0.0
# Zweedse gehaktballetjes met room                                        0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                      0.0
# Zwitserse kaasfondue                                                    0.0
# ‘Nasi’ met Hollandse soepgroente                                        0.0
#
# ingredient                                          (olijf)olie  \
# recipe
#  Andijviestamppot met gebakken salami                       0.0
#  Libanese wraps met appel-koolsalade                        0.0
#  Plaattaart met gegrilde groenten en witte kaas             0.0
#  Zalmspies met sojaglaze van de BBQ                         0.0
# &amp;Suus’ buik-weg-salade                                  0.0
# ...                                                         ...
# Zweedse gehaktballetjes                                     0.0
# Zweedse gehaktballetjes met room                            0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli          0.0
# Zwitserse kaasfondue                                        0.0
# ‘Nasi’ met Hollandse soepgroente                            0.0
#
# ingredient                                          (scharrel)braadworst  \
# recipe
#  Andijviestamppot met gebakken salami                                0.0
#  Libanese wraps met appel-koolsalade                                 0.0
#  Plaattaart met gegrilde groenten en witte kaas                      0.0
#  Zalmspies met sojaglaze van de BBQ                                  0.0
# &amp;Suus’ buik-weg-salade                                           0.0
# ...                                                                  ...
# Zweedse gehaktballetjes                                              0.0
# Zweedse gehaktballetjes met room                                     0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                   0.0
# Zwitserse kaasfondue                                                 0.0
# ‘Nasi’ met Hollandse soepgroente                                     0.0
#
# ingredient                                          (wilde) perzik  \
# recipe
#  Andijviestamppot met gebakken salami                          0.0
#  Libanese wraps met appel-koolsalade                           0.0
#  Plaattaart met gegrilde groenten en witte kaas                0.0
#  Zalmspies met sojaglaze van de BBQ                            0.0
# &amp;Suus’ buik-weg-salade                                     0.0
# ...                                                            ...
# Zweedse gehaktballetjes                                        0.0
# Zweedse gehaktballetjes met room                               0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli             0.0
# Zwitserse kaasfondue                                           0.0
# ‘Nasi’ met Hollandse soepgroente                               0.0
#
# ingredient                                          (witte) quinoa  \
# recipe
#  Andijviestamppot met gebakken salami                          0.0
#  Libanese wraps met appel-koolsalade                           0.0
#  Plaattaart met gegrilde groenten en witte kaas                0.0
#  Zalmspies met sojaglaze van de BBQ                            0.0
# &amp;Suus’ buik-weg-salade                                     0.0
# ...                                                            ...
# Zweedse gehaktballetjes                                        0.0
# Zweedse gehaktballetjes met room                               0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli             0.0
# Zwitserse kaasfondue                                           0.0
# ‘Nasi’ met Hollandse soepgroente                               0.0
#
# ingredient                                          (wittewijn)azijn  \
# recipe
#  Andijviestamppot met gebakken salami                            0.0
#  Libanese wraps met appel-koolsalade                             0.0
#  Plaattaart met gegrilde groenten en witte kaas                  0.0
#  Zalmspies met sojaglaze van de BBQ                              0.0
# &amp;Suus’ buik-weg-salade                                       0.0
# ...                                                              ...
# Zweedse gehaktballetjes                                          0.0
# Zweedse gehaktballetjes met room                                 0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli               0.0
# Zwitserse kaasfondue                                             0.0
# ‘Nasi’ met Hollandse soepgroente                                 0.0
#
# ingredient                                          (zonnebloem)olie  ...  \
# recipe                                                                ...
#  Andijviestamppot met gebakken salami                            0.0  ...
#  Libanese wraps met appel-koolsalade                             0.0  ...
#  Plaattaart met gegrilde groenten en witte kaas                  0.0  ...
#  Zalmspies met sojaglaze van de BBQ                              0.0  ...
# &amp;Suus’ buik-weg-salade                                       0.0  ...
# ...                                                              ...  ...
# Zweedse gehaktballetjes                                          0.0  ...
# Zweedse gehaktballetjes met room                                 0.0  ...
# Zweedse vegaballetjes met aardappel &amp; broccoli               0.0  ...
# Zwitserse kaasfondue                                             0.0  ...
# ‘Nasi’ met Hollandse soepgroente                                 0.0  ...
#
# ingredient                                          zwarte peper  \
# recipe
#  Andijviestamppot met gebakken salami                        0.0
#  Libanese wraps met appel-koolsalade                         0.0
#  Plaattaart met gegrilde groenten en witte kaas              0.0
#  Zalmspies met sojaglaze van de BBQ                          0.0
# &amp;Suus’ buik-weg-salade                                   0.0
# ...                                                          ...
# Zweedse gehaktballetjes                                      0.0
# Zweedse gehaktballetjes met room                             0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli           0.0
# Zwitserse kaasfondue                                         0.0
# ‘Nasi’ met Hollandse soepgroente                             0.0
#
# ingredient                                          zwarte peperkorrels  \
# recipe
#  Andijviestamppot met gebakken salami                               0.0
#  Libanese wraps met appel-koolsalade                                0.0
#  Plaattaart met gegrilde groenten en witte kaas                     0.0
#  Zalmspies met sojaglaze van de BBQ                                 0.0
# &amp;Suus’ buik-weg-salade                                          0.0
# ...                                                                 ...
# Zweedse gehaktballetjes                                             0.0
# Zweedse gehaktballetjes met room                                    0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                  0.0
# Zwitserse kaasfondue                                                0.0
# ‘Nasi’ met Hollandse soepgroente                                    0.0
#
# ingredient                                          zwarte quinoa  \
# recipe
#  Andijviestamppot met gebakken salami                         0.0
#  Libanese wraps met appel-koolsalade                          0.0
#  Plaattaart met gegrilde groenten en witte kaas               0.0
#  Zalmspies met sojaglaze van de BBQ                           0.0
# &amp;Suus’ buik-weg-salade                                    0.0
# ...                                                           ...
# Zweedse gehaktballetjes                                       0.0
# Zweedse gehaktballetjes met room                              0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli            0.0
# Zwitserse kaasfondue                                          0.0
# ‘Nasi’ met Hollandse soepgroente                              0.0
#
# ingredient                                          zwarte rijst  \
# recipe
#  Andijviestamppot met gebakken salami                        0.0
#  Libanese wraps met appel-koolsalade                         0.0
#  Plaattaart met gegrilde groenten en witte kaas              0.0
#  Zalmspies met sojaglaze van de BBQ                          0.0
# &amp;Suus’ buik-weg-salade                                   0.0
# ...                                                          ...
# Zweedse gehaktballetjes                                      0.0
# Zweedse gehaktballetjes met room                             0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli           0.0
# Zwitserse kaasfondue                                         0.0
# ‘Nasi’ met Hollandse soepgroente                             0.0
#
# ingredient                                          zwarte sesamzaadje  \
# recipe
#  Andijviestamppot met gebakken salami                              0.0
#  Libanese wraps met appel-koolsalade                               0.0
#  Plaattaart met gegrilde groenten en witte kaas                    0.0
#  Zalmspies met sojaglaze van de BBQ                                0.0
# &amp;Suus’ buik-weg-salade                                         0.0
# ...                                                                ...
# Zweedse gehaktballetjes                                            0.0
# Zweedse gehaktballetjes met room                                   0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                 0.0
# Zwitserse kaasfondue                                               0.0
# ‘Nasi’ met Hollandse soepgroente                                   0.0
#
# ingredient                                          zwarte tagliatelle  \
# recipe
#  Andijviestamppot met gebakken salami                              0.0
#  Libanese wraps met appel-koolsalade                               0.0
#  Plaattaart met gegrilde groenten en witte kaas                    0.0
#  Zalmspies met sojaglaze van de BBQ                                0.0
# &amp;Suus’ buik-weg-salade                                         0.0
# ...                                                                ...
# Zweedse gehaktballetjes                                            0.0
# Zweedse gehaktballetjes met room                                   0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                 0.0
# Zwitserse kaasfondue                                               0.0
# ‘Nasi’ met Hollandse soepgroente                                   0.0
#
# ingredient                                          zwarte-peperkorrels  \
# recipe
#  Andijviestamppot met gebakken salami                               0.0
#  Libanese wraps met appel-koolsalade                                0.0
#  Plaattaart met gegrilde groenten en witte kaas                     0.0
#  Zalmspies met sojaglaze van de BBQ                                 0.0
# &amp;Suus’ buik-weg-salade                                          0.0
# ...                                                                 ...
# Zweedse gehaktballetjes                                             0.0
# Zweedse gehaktballetjes met room                                    0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                  0.0
# Zwitserse kaasfondue                                                0.0
# ‘Nasi’ met Hollandse soepgroente                                    0.0
#
# ingredient                                          zwarteolijvenplakjes  \
# recipe
#  Andijviestamppot met gebakken salami                                0.0
#  Libanese wraps met appel-koolsalade                                 0.0
#  Plaattaart met gegrilde groenten en witte kaas                      0.0
#  Zalmspies met sojaglaze van de BBQ                                  0.0
# &amp;Suus’ buik-weg-salade                                           0.0
# ...                                                                  ...
# Zweedse gehaktballetjes                                              0.0
# Zweedse gehaktballetjes met room                                     0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                   0.0
# Zwitserse kaasfondue                                                 0.0
# ‘Nasi’ met Hollandse soepgroente                                     0.0
#
# ingredient                                          zwartepeperkorrel  \
# recipe
#  Andijviestamppot met gebakken salami                             0.0
#  Libanese wraps met appel-koolsalade                              0.0
#  Plaattaart met gegrilde groenten en witte kaas                   0.0
#  Zalmspies met sojaglaze van de BBQ                               0.0
# &amp;Suus’ buik-weg-salade                                        0.0
# ...                                                               ...
# Zweedse gehaktballetjes                                           0.0
# Zweedse gehaktballetjes met room                                  0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                0.0
# Zwitserse kaasfondue                                              0.0
# ‘Nasi’ met Hollandse soepgroente                                  0.0
#
# ingredient                                          zwijnsteak
# recipe
#  Andijviestamppot met gebakken salami                      0.0
#  Libanese wraps met appel-koolsalade                       0.0
#  Plaattaart met gegrilde groenten en witte kaas            0.0
#  Zalmspies met sojaglaze van de BBQ                        0.0
# &amp;Suus’ buik-weg-salade                                 0.0
# ...                                                        ...
# Zweedse gehaktballetjes                                    0.0
# Zweedse gehaktballetjes met room                           0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli         0.0
# Zwitserse kaasfondue                                       0.0
# ‘Nasi’ met Hollandse soepgroente                           0.0
#
# [4616 rows x 4797 columns]

# %%
tags_pivot
# Out:
# tag                                                 5-ingrediënten  \
# recipe
#  Andijviestamppot met gebakken salami                          0.0
#  Libanese wraps met appel-koolsalade                           0.0
#  Plaattaart met gegrilde groenten en witte kaas                1.0
#  Zalmspies met sojaglaze van de BBQ                            0.0
# &amp;Suus’ buik-weg-salade                                     0.0
# ...                                                            ...
# Zweedse gehaktballetjes                                        0.0
# Zweedse gehaktballetjes met room                               0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli             0.0
# Zwitserse kaasfondue                                           0.0
# ‘Nasi’ met Hollandse soepgroente                               1.0
#
# tag                                                 amerikaans  argentijns  \
# recipe
#  Andijviestamppot met gebakken salami                      0.0         0.0
#  Libanese wraps met appel-koolsalade                       0.0         0.0
#  Plaattaart met gegrilde groenten en witte kaas            0.0         0.0
#  Zalmspies met sojaglaze van de BBQ                        0.0         0.0
# &amp;Suus’ buik-weg-salade                                 0.0         0.0
# ...                                                        ...         ...
# Zweedse gehaktballetjes                                    0.0         0.0
# Zweedse gehaktballetjes met room                           0.0         0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli         0.0         0.0
# Zwitserse kaasfondue                                       0.0         0.0
# ‘Nasi’ met Hollandse soepgroente                           0.0         0.0
#
# tag                                                 aziatisch  bakken  \
# recipe
#  Andijviestamppot met gebakken salami                     0.0     1.0
#  Libanese wraps met appel-koolsalade                      0.0     0.0
#  Plaattaart met gegrilde groenten en witte kaas           0.0     0.0
#  Zalmspies met sojaglaze van de BBQ                       1.0     0.0
# &amp;Suus’ buik-weg-salade                                0.0     0.0
# ...                                                       ...     ...
# Zweedse gehaktballetjes                                   0.0     1.0
# Zweedse gehaktballetjes met room                          0.0     1.0
# Zweedse vegaballetjes met aardappel &amp; broccoli        0.0     1.0
# Zwitserse kaasfondue                                      0.0     0.0
# ‘Nasi’ met Hollandse soepgroente                          1.0     0.0
#
# tag                                                 barbecue  bijgerecht  \
# recipe
#  Andijviestamppot met gebakken salami                    0.0         0.0
#  Libanese wraps met appel-koolsalade                     0.0         0.0
#  Plaattaart met gegrilde groenten en witte kaas          0.0         0.0
#  Zalmspies met sojaglaze van de BBQ                      1.0         0.0
# &amp;Suus’ buik-weg-salade                               0.0         0.0
# ...                                                      ...         ...
# Zweedse gehaktballetjes                                  0.0         0.0
# Zweedse gehaktballetjes met room                         0.0         1.0
# Zweedse vegaballetjes met aardappel &amp; broccoli       0.0         0.0
# Zwitserse kaasfondue                                     0.0         0.0
# ‘Nasi’ met Hollandse soepgroente                         0.0         0.0
#
# tag                                                 biologisch  blancheren  \
# recipe
#  Andijviestamppot met gebakken salami                      0.0         0.0
#  Libanese wraps met appel-koolsalade                       0.0         0.0
#  Plaattaart met gegrilde groenten en witte kaas            0.0         0.0
#  Zalmspies met sojaglaze van de BBQ                        0.0         0.0
# &amp;Suus’ buik-weg-salade                                 0.0         0.0
# ...                                                        ...         ...
# Zweedse gehaktballetjes                                    0.0         0.0
# Zweedse gehaktballetjes met room                           0.0         0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli         0.0         0.0
# Zwitserse kaasfondue                                       0.0         0.0
# ‘Nasi’ met Hollandse soepgroente                           0.0         0.0
#
# tag                                                 borrel  ...  verjaardag  \
# recipe                                                      ...
#  Andijviestamppot met gebakken salami                  0.0  ...         0.0
#  Libanese wraps met appel-koolsalade                   0.0  ...         0.0
#  Plaattaart met gegrilde groenten en witte kaas        0.0  ...         0.0
#  Zalmspies met sojaglaze van de BBQ                    0.0  ...         0.0
# &amp;Suus’ buik-weg-salade                             0.0  ...         0.0
# ...                                                    ...  ...         ...
# Zweedse gehaktballetjes                                0.0  ...         0.0
# Zweedse gehaktballetjes met room                       0.0  ...         0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli     0.0  ...         0.0
# Zwitserse kaasfondue                                   0.0  ...         0.0
# ‘Nasi’ met Hollandse soepgroente                       0.0  ...         0.0
#
# tag                                                 vietnamees  \
# recipe
#  Andijviestamppot met gebakken salami                      0.0
#  Libanese wraps met appel-koolsalade                       0.0
#  Plaattaart met gegrilde groenten en witte kaas            0.0
#  Zalmspies met sojaglaze van de BBQ                        0.0
# &amp;Suus’ buik-weg-salade                                 0.0
# ...                                                        ...
# Zweedse gehaktballetjes                                    0.0
# Zweedse gehaktballetjes met room                           0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli         0.0
# Zwitserse kaasfondue                                       0.0
# ‘Nasi’ met Hollandse soepgroente                           0.0
#
# tag                                                 vooraf te maken  \
# recipe
#  Andijviestamppot met gebakken salami                           0.0
#  Libanese wraps met appel-koolsalade                            0.0
#  Plaattaart met gegrilde groenten en witte kaas                 0.0
#  Zalmspies met sojaglaze van de BBQ                             0.0
# &amp;Suus’ buik-weg-salade                                      0.0
# ...                                                             ...
# Zweedse gehaktballetjes                                         0.0
# Zweedse gehaktballetjes met room                                0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli              0.0
# Zwitserse kaasfondue                                            0.0
# ‘Nasi’ met Hollandse soepgroente                                1.0
#
# tag                                                 voorgerecht  \
# recipe
#  Andijviestamppot met gebakken salami                       0.0
#  Libanese wraps met appel-koolsalade                        0.0
#  Plaattaart met gegrilde groenten en witte kaas             0.0
#  Zalmspies met sojaglaze van de BBQ                         0.0
# &amp;Suus’ buik-weg-salade                                  0.0
# ...                                                         ...
# Zweedse gehaktballetjes                                     0.0
# Zweedse gehaktballetjes met room                            0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli          0.0
# Zwitserse kaasfondue                                        0.0
# ‘Nasi’ met Hollandse soepgroente                            0.0
#
# tag                                                 wat eten we vandaag  wrap  \
# recipe
#  Andijviestamppot met gebakken salami                               1.0   0.0
#  Libanese wraps met appel-koolsalade                                1.0   1.0
#  Plaattaart met gegrilde groenten en witte kaas                     1.0   0.0
#  Zalmspies met sojaglaze van de BBQ                                 0.0   0.0
# &amp;Suus’ buik-weg-salade                                          0.0   0.0
# ...                                                                 ...   ...
# Zweedse gehaktballetjes                                             0.0   0.0
# Zweedse gehaktballetjes met room                                    0.0   0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli                  1.0   0.0
# Zwitserse kaasfondue                                                0.0   0.0
# ‘Nasi’ met Hollandse soepgroente                                    1.0   0.0
#
# tag                                                 zonder vlees  \
# recipe
#  Andijviestamppot met gebakken salami                        0.0
#  Libanese wraps met appel-koolsalade                         0.0
#  Plaattaart met gegrilde groenten en witte kaas              0.0
#  Zalmspies met sojaglaze van de BBQ                          0.0
# &amp;Suus’ buik-weg-salade                                   0.0
# ...                                                          ...
# Zweedse gehaktballetjes                                      0.0
# Zweedse gehaktballetjes met room                             0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli           0.0
# Zwitserse kaasfondue                                         0.0
# ‘Nasi’ met Hollandse soepgroente                             0.0
#
# tag                                                 zonder vlees/vis  \
# recipe
#  Andijviestamppot met gebakken salami                            0.0
#  Libanese wraps met appel-koolsalade                             0.0
#  Plaattaart met gegrilde groenten en witte kaas                  1.0
#  Zalmspies met sojaglaze van de BBQ                              0.0
# &amp;Suus’ buik-weg-salade                                       0.0
# ...                                                              ...
# Zweedse gehaktballetjes                                          0.0
# Zweedse gehaktballetjes met room                                 0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli               0.0
# Zwitserse kaasfondue                                             1.0
# ‘Nasi’ met Hollandse soepgroente                                 0.0
#
# tag                                                 zuid-afrikaans  \
# recipe
#  Andijviestamppot met gebakken salami                          0.0
#  Libanese wraps met appel-koolsalade                           0.0
#  Plaattaart met gegrilde groenten en witte kaas                0.0
#  Zalmspies met sojaglaze van de BBQ                            0.0
# &amp;Suus’ buik-weg-salade                                     0.0
# ...                                                            ...
# Zweedse gehaktballetjes                                        0.0
# Zweedse gehaktballetjes met room                               0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli             0.0
# Zwitserse kaasfondue                                           0.0
# ‘Nasi’ met Hollandse soepgroente                               0.0
#
# tag                                                 zuid-amerikaans
# recipe
#  Andijviestamppot met gebakken salami                           0.0
#  Libanese wraps met appel-koolsalade                            0.0
#  Plaattaart met gegrilde groenten en witte kaas                 0.0
#  Zalmspies met sojaglaze van de BBQ                             0.0
# &amp;Suus’ buik-weg-salade                                      0.0
# ...                                                             ...
# Zweedse gehaktballetjes                                         0.0
# Zweedse gehaktballetjes met room                                0.0
# Zweedse vegaballetjes met aardappel &amp; broccoli              0.0
# Zwitserse kaasfondue                                            0.0
# ‘Nasi’ met Hollandse soepgroente                                0.0
#
# [4616 rows x 112 columns]
